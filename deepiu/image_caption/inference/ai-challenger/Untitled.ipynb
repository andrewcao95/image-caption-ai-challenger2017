# %%
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

names = map(str, [x + 1 for x in range(9)])
x = range(len(names))
cider = [1.801, 1.816, 1.834, 1.854, 1.8634, 1.86952, 1.8870, 1.8919, 1.8941]
#bleu4 =[0.567, 0.572, 0.578, 0.5829, 0.5845, 0.5867, 0.5906, 0.5921, 0.5923]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
#pl.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, cider, marker='o', mec='r', mfc='w',label=u'cider')
#plt.plot(x, bleu4, marker='*', ms=10,label=u'bleu4')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=45)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"ensemble num models\n(123)InceptionResnetV2,(456)InceptionV4,(789)Nasnet") #X轴标签
plt.ylabel("cider") #Y轴标签
plt.title("ensemble performance: cider") #标题

plt.show()

# %%
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

names = map(str, [x + 1 for x in range(9)])
x = range(len(names))
bleu4 = [0.567, 0.572, 0.578, 0.5829, 0.5845, 0.58672, 0.5906, 0.5921, 0.5925]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
#pl.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, bleu4, marker='o', mec='r', mfc='w',label=u'bleu4')
#plt.plot(x, bleu4, marker='*', ms=10,label=u'bleu4')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=45)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"ensemble num models\n(123)InceptionResnetV2,(456)InceptionV4,(789)Nasnet") #X轴标签
plt.ylabel("bleu4") #Y轴标签
plt.title("ensemble performance: bleu4") #标题

plt.show()
